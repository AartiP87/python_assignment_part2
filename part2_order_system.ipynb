# %% [markdown]
# <a href="https://colab.research.google.com/github/AartiP87/python_assignment_part2/blob/main/part2_order_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===================== DATA =====================

menu = {
    "Paneer Tikka":   {"category": "Starters",  "price": 180.0, "available": True},
    "Chicken Wings":  {"category": "Starters",  "price": 220.0, "available": False},
    "Veg Soup":       {"category": "Starters",  "price": 120.0, "available": True},
    "Butter Chicken": {"category": "Mains",     "price": 320.0, "available": True},
    "Dal Tadka":      {"category": "Mains",     "price": 180.0, "available": True},
    "Veg Biryani":    {"category": "Mains",     "price": 250.0, "available": True},
    "Garlic Naan":    {"category": "Mains",     "price": 40.0, "available": True},
    "Gulab Jamun":    {"category": "Desserts",  "price": 90.0, "available": True},
    "Rasgulla":       {"category": "Desserts",  "price": 80.0, "available": True},
    "Ice Cream":      {"category": "Desserts",  "price": 110.0, "available": False},
}

inventory = {
    "Paneer Tikka":   {"stock": 10, "reorder_level": 3},
    "Chicken Wings":  {"stock": 8, "reorder_level": 2},
    "Veg Soup":       {"stock": 15, "reorder_level": 5},
    "Butter Chicken": {"stock": 12, "reorder_level": 4},
    "Dal Tadka":      {"stock": 20, "reorder_level": 5},
    "Veg Biryani":    {"stock": 6, "reorder_level": 3},
    "Garlic Naan":    {"stock": 30, "reorder_level": 10},
    "Gulab Jamun":    {"stock": 5, "reorder_level": 2},
    "Rasgulla":       {"stock": 4, "reorder_level": 3},
    "Ice Cream":      {"stock": 7, "reorder_level": 4},
}

sales_log = {
    "2025-01-01": [
        {"order_id": 1, "items": ["Paneer Tikka", "Garlic Naan"], "total": 220.0},
        {"order_id": 2, "items": ["Gulab Jamun", "Veg Soup"], "total": 210.0},
        {"order_id": 3, "items": ["Butter Chicken", "Garlic Naan"], "total": 360.0},
    ],
    "2025-01-02": [
        {"order_id": 4, "items": ["Dal Tadka", "Garlic Naan"], "total": 220.0},
        {"order_id": 5, "items": ["Veg Biryani", "Gulab Jamun"], "total": 340.0},
    ],
    "2025-01-03": [
        {"order_id": 6, "items": ["Paneer Tikka", "Rasgulla"], "total": 260.0},
        {"order_id": 7, "items": ["Butter Chicken", "Veg Biryani"], "total": 570.0},
        {"order_id": 8, "items": ["Garlic Naan", "Gulab Jamun"], "total": 130.0},
    ],
    "2025-01-04": [
        {"order_id": 9, "items": ["Dal Tadka", "Garlic Naan", "Rasgulla"], "total": 300.0},
        {"order_id": 10, "items": ["Paneer Tikka", "Gulab Jamun"], "total": 270.0},
    ],
}

# ===================== TASK 1 =====================

print("MENU BY CATEGORY")

categories = set([item["category"] for item in menu.values()])

for category in categories:
    print("=====", category, "=====")
    for name, details in menu.items():
        if details["category"] == category:
            status = "Available" if details["available"] else "Unavailable"
            print(name, "₹", details["price"], "[", status, "]")

# Stats
total_items = len(menu)
available_items = sum(1 for item in menu.values() if item["available"])

most_expensive = max(menu.items(), key=lambda x: x[1]["price"])

cheap_items = [(name, data["price"]) for name, data in menu.items() if data["price"] < 150]

print("Total items:", total_items)
print("Available items:", available_items)
print("Most expensive:", most_expensive[0], most_expensive[1]["price"])

print("Items under 150:")
for item in cheap_items:
    print(item[0], item[1])
# Out:
# MENU BY CATEGORY
# ===== Starters =====
# Paneer Tikka ₹ 180.0 [ Available ]
# Chicken Wings ₹ 220.0 [ Unavailable ]
# Veg Soup ₹ 120.0 [ Available ]
# ===== Mains =====
# Butter Chicken ₹ 320.0 [ Available ]
# Dal Tadka ₹ 180.0 [ Available ]
# Veg Biryani ₹ 250.0 [ Available ]
# Garlic Naan ₹ 40.0 [ Available ]
# ===== Desserts =====
# Gulab Jamun ₹ 90.0 [ Available ]
# Rasgulla ₹ 80.0 [ Available ]
# Ice Cream ₹ 110.0 [ Unavailable ]
# Total items: 10
# Available items: 8
# Most expensive: Butter Chicken 320.0
# Items under 150:
# Veg Soup 120.0
# Garlic Naan 40.0
# Gulab Jamun 90.0
# Rasgulla 80.0
# Ice Cream 110.0

# %%
# ===================== TASK 2 =====================

cart = []

def add_to_cart(item, quantity):
    if item not in menu:
        print("Item not found:", item)
        return

    if not menu[item]["available"]:
        print("Item unavailable:", item)
        return

    for entry in cart:
        if entry["item"] == item:
            entry["quantity"] += quantity
            print("Updated:", item)
            return

    cart.append({"item": item, "quantity": quantity, "price": menu[item]["price"]})
    print("Added:", item)

def remove_from_cart(item):
    for entry in cart:
        if entry["item"] == item:
            cart.remove(entry)
            print("Removed:", item)
            return
    print("Item not in cart:", item)

def print_cart():
    print("Current cart:")
    for entry in cart:
        print(entry)

# Simulation
add_to_cart("Paneer Tikka", 2)
print_cart()

add_to_cart("Gulab Jamun", 1)
print_cart()

add_to_cart("Paneer Tikka", 1)
print_cart()

add_to_cart("Mystery Burger", 1)
add_to_cart("Chicken Wings", 1)

remove_from_cart("Gulab Jamun")
print_cart()

# Order summary
subtotal = 0
print("Order Summary")

for entry in cart:
    total = entry["quantity"] * entry["price"]
    subtotal += total
    print(entry["item"], "x", entry["quantity"], "₹", total)

gst = subtotal * 0.05
total_payable = subtotal + gst

print("Subtotal:", subtotal)
print("GST:", gst)
print("Total:", total_payable)
# Out:
# Added: Paneer Tikka
# Current cart:
# {'item': 'Paneer Tikka', 'quantity': 2, 'price': 180.0}
# Added: Gulab Jamun
# Current cart:
# {'item': 'Paneer Tikka', 'quantity': 2, 'price': 180.0}
# {'item': 'Gulab Jamun', 'quantity': 1, 'price': 90.0}
# Updated: Paneer Tikka
# Current cart:
# {'item': 'Paneer Tikka', 'quantity': 3, 'price': 180.0}
# {'item': 'Gulab Jamun', 'quantity': 1, 'price': 90.0}
# Item not found: Mystery Burger
# Item unavailable: Chicken Wings
# Removed: Gulab Jamun
# Current cart:
# {'item': 'Paneer Tikka', 'quantity': 3, 'price': 180.0}
# Order Summary
# Paneer Tikka x 3 ₹ 540.0
# Subtotal: 540.0
# GST: 27.0
# Total: 567.0

# %%
# ===================== TASK 3 =====================

import copy

inventory_backup = copy.deepcopy(inventory)

# change value to prove deep copy
inventory["Paneer Tikka"]["stock"] = 5

print("Changed inventory:", inventory["Paneer Tikka"])
print("Backup inventory:", inventory_backup["Paneer Tikka"])

# restore
inventory = copy.deepcopy(inventory_backup)

# deduct stock
for entry in cart:
    item = entry["item"]
    qty = entry["quantity"]

    if inventory[item]["stock"] >= qty:
        inventory[item]["stock"] -= qty
    else:
        print("Not enough stock for", item)
        inventory[item]["stock"] = 0

# reorder alerts
for item, data in inventory.items():
    if data["stock"] <= data["reorder_level"]:
        print("Reorder Alert:", item, "Stock:", data["stock"])

print("Final inventory:", inventory)
print("Backup inventory:", inventory_backup)
# Out:
# Changed inventory: {'stock': 5, 'reorder_level': 3}
# Backup inventory: {'stock': 10, 'reorder_level': 3}
# Final inventory: {'Paneer Tikka': {'stock': 7, 'reorder_level': 3}, 'Chicken Wings': {'stock': 8, 'reorder_level': 2}, 'Veg Soup': {'stock': 15, 'reorder_level': 5}, 'Butter Chicken': {'stock': 12, 'reorder_level': 4}, 'Dal Tadka': {'stock': 20, 'reorder_level': 5}, 'Veg Biryani': {'stock': 6, 'reorder_level': 3}, 'Garlic Naan': {'stock': 30, 'reorder_level': 10}, 'Gulab Jamun': {'stock': 5, 'reorder_level': 2}, 'Rasgulla': {'stock': 4, 'reorder_level': 3}, 'Ice Cream': {'stock': 7, 'reorder_level': 4}}
# ...

# %%
# ===================== TASK 4 =====================

print("Revenue per day")

day_totals = {}

for day, orders in sales_log.items():
    total = sum(order["total"] for order in orders)
    day_totals[day] = total
    print(day, total)

best_day = max(day_totals, key=day_totals.get)
print("Best day:", best_day)

# most ordered item
item_count = {}

for orders in sales_log.values():
    for order in orders:
        for item in order["items"]:
            item_count[item] = item_count.get(item, 0) + 1

most_ordered = max(item_count, key=item_count.get)
print("Most ordered item:", most_ordered)

# add new day
sales_log["2025-01-05"] = [
    {"order_id": 11, "items": ["Butter Chicken", "Gulab Jamun", "Garlic Naan"], "total": 490.0},
    {"order_id": 12, "items": ["Paneer Tikka", "Rasgulla"], "total": 260.0},
]

print("Updated revenue")

for day, orders in sales_log.items():
    total = sum(order["total"] for order in orders)
    print(day, total)

# enumerate orders
count = 1
for day, orders in sales_log.items():
    for order in orders:
        print(count, day, "Order", order["order_id"], order["total"], order["items"])
        count += 1
# Out:
# Revenue per day
# 2025-01-01 790.0
# 2025-01-02 560.0
# 2025-01-03 960.0
# 2025-01-04 570.0
# Best day: 2025-01-03
# Most ordered item: Garlic Naan
# Updated revenue
# 2025-01-01 790.0
# 2025-01-02 560.0
# 2025-01-03 960.0
# 2025-01-04 570.0
# 2025-01-05 750.0
# 1 2025-01-01 Order 1 220.0 ['Paneer Tikka', 'Garlic Naan']
# 2 2025-01-01 Order 2 210.0 ['Gulab Jamun', 'Veg Soup']
# 3 2025-01-01 Order 3 360.0 ['Butter Chicken', 'Garlic Naan']
# 4 2025-01-02 Order 4 220.0 ['Dal Tadka', 'Garlic Naan']
# 5 2025-01-02 Order 5 340.0 ['Veg Biryani', 'Gulab Jamun']
# 6 2025-01-03 Order 6 260.0 ['Paneer Tikka', 'Rasgulla']
# 7 2025-01-03 Order 7 570.0 ['Butter Chicken', 'Veg Biryani']
# 8 2025-01-03 Order 8 130.0 ['Garlic Naan', 'Gulab Jamun']
# 9 2025-01-04 Order 9 300.0 ['Dal Tadka', 'Garlic Naan', 'Rasgulla']
# 10 2025-01-04 Order 10 270.0 ['Paneer Tikka', 'Gulab Jamun']
# 11 2025-01-05 Order 11 490.0 ['Butter Chicken', 'Gulab Jamun', 'Garlic Naan']
# ...
